# %%
import json
import time
import argparse
from pprint import pprint
from datetime import datetime

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains


def write_results_to_json(results):
    """ Write the scraped results to a timestamped JSON output file. """
    timestamp = datetime.strftime(datetime.now(), "%Y%m%dT%H%M%S")
    filename = f"results_{timestamp}.json"
    with open(filename, 'w') as outfile:
        json.dump(results, outfile)


def load_results_json(file):
    with open(file, 'r') as infile:
        data = json.load(infile)
    return data


def parse_review_text(text):
    """ Parse the raw text from a scraped review.
    Reviews look like, for example:

        riani wahyu prajanti
        December 29, 2019
        
        1
        
        The app is really easy to use. Lots of information about wines and especially the reviews
        help me in buying wines. Not all the time though, sometimes i bought wines with 3.3 or 3.5 review
        but those taste quite good! I would really like it if there is a feature to share the wine cellars.
        My boyfriend has scanned all of the wines we have and added those to his cellar list and i
        can't have the list on my account, too bad!

    """

    text = text.split('\n')
    """ Vivino support often replies to negative reviews, and in that event changes how we have
        to parse things. These reviews look something like, for example:

        'Olivia Andrew\nDecember 4, 2019\n\ue8dc\n8\n\ue5d4\nToo Complicated. Takes too much time to navigate.\n
        VivinoDecember 5, 2019\n
        We’re sorry to hear that. Would you mind contacting us through the app (Contact Vivino) or through 
        our web form: https://www.vivino.com/support? We really want to solve any issues you might experience. 
        Looking forward to hearing from you.'
    """
    vivino_response_text = ''
    # print(len(text))
    if len(text) <= 6:
        # No Vivino support response present
        raw_name = text[0]
        raw_date = text[1]
        raw_text = text[-1]
    else:
        # Vivino support response must be present
        raw_name = text[0]
        raw_date = text[1]
        raw_text = text[5]
        vivino_response_text = text[-1]
    return (raw_name, raw_date, raw_text, vivino_response_text)


class ShowMoreButton(object):

    def __init__(self, driver):
        self.driver = driver
        self._css_selector = '#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div.PFAhAf > div > span > span'

    def is_present(self):
        """ Determine if 'SHOW MORE' reviews button is currently present on page."""
        try:
            btn_text = self.driver.find_element_by_css_selector(self._css_selector).text
            if btn_text == 'SHOW MORE':
                return True
            else:
                return False
        except NoSuchElementException:
            return False

    def move_to(self):
        """ Move to the button location on the page. """
        # Move to the next review

        button = self.driver.find_element_by_css_selector(self._css_selector)
        ActionChains(self.driver).move_to_element(button).perform()

    def click(self):
        """ Click the show more button. """
        WebDriverWait(self.driver, 5).until(EC.element_to_be_clickable((By.CSS_SELECTOR, self._css_selector))).click()

    def try_to_show_more_reviews(self):
        if self.is_present():
            # print("'SHOW MORE' button available - clicking to load more reviews now...")
            self.move_to()
            self.click()
        else:
            # print("'SHOW MORE' button not currently present on page!")
            pass


class ReviewStars(object):

    def __init__(self, driver, review_num):
        self.driver = driver
        self.review_num = review_num
        self._css_selector = f"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child({review_num}) > div > div.d15Mdf.bAhLNe > div.xKpxId.zc7KVe > div.bAhLNe.kx8XBd > div > span.nt2C1d > div > div"

        self._rank = ()

    @property
    def rank(self):
        text = self.driver.find_element_by_css_selector(self._css_selector).get_attribute('aria-label')
        s = text.split(" ")
        # Review star ranks are on a x/5 scale, so
        # we'll return a tuple like, for example (4, 5)
        # to denote 4/5 stars.
        self._rank = (int(s[1]), 5)
        return self._rank


class Review(object):

    def __init__(self, driver, review_num):
        self._driver = driver
        self.review_num = review_num
        self._css_selector = f'#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child({review_num})'
        self._element = self._driver.find_element_by_css_selector(self._css_selector)

        self._full_review_css_selector = f"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child({self.review_num}) > div > div.d15Mdf.bAhLNe > div.UD7Dzf > span:nth-child(1) > div > button"

        self._raw_text = ''

        # Parsed values: Reviwer name, date, review text
        self._name = ''
        self._date = ''
        self._text = ''
        self._vivino_response = ''

    @property
    def raw_text(self):
        self._raw_text = self._element.text
        return self._raw_text

    @property
    def name(self):
        self._name = parse_review_text(self.raw_text)[0]
        return self._name

    @property
    def date(self):
        self._date = parse_review_text(self.raw_text)[1]
        return self._date

    @property
    def text(self):
        self._text = parse_review_text(self.raw_text)[2]
        return self._text

    @property
    def vivino_response(self):
        self._vivino_response = parse_review_text(self.raw_text)[3]
        return self._vivino_response

    def move_to(self):
        """ Move to the review location on the page. """
        r = self._driver.find_element_by_css_selector(self._css_selector)
        ActionChains(self._driver).move_to_element(r).perform()

    def is_expandable(self):
        """ Check if 'Full Review' button present in review to show more text. """
        try:
            btn_text = self._element.find_element_by_css_selector(self._full_review_css_selector).text
            if btn_text == "Full Review":
                return True
            else:
                return False
        except NoSuchElementException:
            # print("Review cannot be expanded!")
            return False

    def expand(self):
        if self.is_expandable():
            # self._driver.find_element_by_css_selector(self._full_review_css_selector).click()
            WebDriverWait(self._driver, 5).until(
                EC.element_to_be_clickable((By.CSS_SELECTOR, self._full_review_css_selector))).click()


# def main(args):
#     """ Main entry point for application. """

#     max_reviews = args.max_reviews
#     print(f"***** STARTING SCRAPER *****")

#     # Google app store Vivino page URL
#     vivino_url = "https://play.google.com/store/apps/details?id=vivino.web.app&showAllReviews=true"

#     # Setup the driver.
#     driver = webdriver.Chrome()
#     driver.get(vivino_url)

#     show_more_btn = ShowMoreButton(driver)

#     # max_reviews = 10
#     review_num = 1

#     results = []
#     while True:

#         if review_num > max_reviews:
#             break

#         print(f"Getting Review #{review_num}/{max_reviews}")

#         try:

#             # Try to click the 'Show More' reviews button if available on page
#             show_more_btn.try_to_show_more_reviews()

#             # Parse the review
#             review = Review(driver, review_num)
#             review.move_to()
#             if review.is_expandable():
#                 review.expand()

#             stars = ReviewStars(driver, review_num)
#             # print(review.name, review.date, review.text, stars.rank)

#             results.append({
#                 "name": review.name,
#                 "date": review.date,
#                 "text": review.text,
#                 "stars": stars.rank,
#                 "vivino_response": review.vivino_response,
#             })
#         except Exception as e:
#             print(f"Exception occurred on review #{review_num}. Skipping review. Exception: \n {e}")

#         review_num += 1
#         time.sleep(1)

#     # Shutdown the Chrome driver
#     # driver.close()

#     # pprint(results)
#     print(f"**** FINISHED! SUCCESSFULLY SCRAPED {len(results)} TOTAL REVIEWS! ****")

#     # Save the scraped results to a JSON file
#     write_results_to_json(results)


# if __name__ == "__main__":

#     # Parse command line args
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--max_reviews", type=int, default=10, help="Maximum number of reviews to scrape.")
#     args = parser.parse_args()

#     # Run the scraper
#     main(args)

# %%
""" Main entry point for application. """
MAX_REVIEWS = 30000
# MAX_REVIEWS = 500

max_reviews = MAX_REVIEWS # args.max_reviews
print(f"***** STARTING SCRAPER *****")

# Google app store Vivino page URL
vivino_url = "https://play.google.com/store/apps/details?id=vivino.web.app&showAllReviews=true"

# Setup the driver.
driver = webdriver.Chrome()
driver.get(vivino_url)

# Intitialize the review counter
review_num = 1

results = []
while True:

    if review_num > max_reviews:
        break

    print(f"Getting Review #{review_num}/{max_reviews}")

    try:

        # Try to click the 'Show More' reviews button if available on page
        show_more_btn = ShowMoreButton(driver)
        show_more_btn.try_to_show_more_reviews()

        # Parse the review
        review = Review(driver, review_num)
        review.move_to()
        if review.is_expandable():
            review.expand()

        stars = ReviewStars(driver, review_num)
        # print(review.name, review.date, review.text, stars.rank)
        
        # Try to click the 'Show More' reviews button if available on page
        show_more_btn = ShowMoreButton(driver)
        show_more_btn.try_to_show_more_reviews()

        results.append({
            "name": review.name,
            "date": review.date,
            "text": review.text,
            "stars": stars.rank,
            "vivino_response": review.vivino_response,
        })
    except Exception as e:
        print(f"Exception occurred on review #{review_num}. Skipping review. Exception: \n {e}")
        time.sleep(3)

    review_num += 1
    # time.sleep(1)

# Shutdown the Chrome driver
# driver.close()

# pprint(results)
print(f"**** FINISHED! SUCCESSFULLY SCRAPED {len(results)} TOTAL REVIEWS! ****")

# Save the scraped results to a JSON file
write_results_to_json(results)
# Out:
# ***** STARTING SCRAPER *****
# Getting Review #1/30000
# Getting Review #2/30000
# Getting Review #3/30000
# Getting Review #4/30000
# Getting Review #5/30000
# Getting Review #6/30000
# Getting Review #7/30000
# Getting Review #8/30000
# Getting Review #9/30000
# Getting Review #10/30000
# Getting Review #11/30000
# Getting Review #12/30000
# Getting Review #13/30000
# Getting Review #14/30000
# Getting Review #15/30000
# Getting Review #16/30000
# Getting Review #17/30000
# Getting Review #18/30000
# Getting Review #19/30000
# Getting Review #20/30000
# Getting Review #21/30000
# Getting Review #22/30000
# Getting Review #23/30000
# Getting Review #24/30000
# Getting Review #25/30000
# Getting Review #26/30000
# Getting Review #27/30000
# Getting Review #28/30000
# Getting Review #29/30000
# Getting Review #30/30000
# Getting Review #31/30000
# Getting Review #32/30000
# Getting Review #33/30000
# Getting Review #34/30000
# Getting Review #35/30000
# Getting Review #36/30000
# Getting Review #37/30000
# Getting Review #38/30000
# Getting Review #39/30000
# Getting Review #40/30000
# Getting Review #41/30000
# Getting Review #42/30000
# Getting Review #43/30000
# Getting Review #44/30000
# Getting Review #45/30000
# Getting Review #46/30000
# Getting Review #47/30000
# Getting Review #48/30000
# Getting Review #49/30000
# Getting Review #50/30000
# Getting Review #51/30000
# Getting Review #52/30000
# Getting Review #53/30000
# Getting Review #54/30000
# Getting Review #55/30000
# Getting Review #56/30000
# Getting Review #57/30000
# Getting Review #58/30000
# Getting Review #59/30000
# Getting Review #60/30000
# Getting Review #61/30000
# Getting Review #62/30000
# Getting Review #63/30000
# Getting Review #64/30000
# Getting Review #65/30000
# Getting Review #66/30000
# Getting Review #67/30000
# Getting Review #68/30000
# Getting Review #69/30000
# Getting Review #70/30000
# Getting Review #71/30000
# Getting Review #72/30000
# Getting Review #73/30000
# Getting Review #74/30000
# Getting Review #75/30000
# Getting Review #76/30000
# Getting Review #77/30000
# Getting Review #78/30000
# Getting Review #79/30000
# Getting Review #80/30000
# Getting Review #81/30000
# Getting Review #82/30000
# Getting Review #83/30000
# Getting Review #84/30000
# Getting Review #85/30000
# Getting Review #86/30000
# Getting Review #87/30000
# Getting Review #88/30000
# Getting Review #89/30000
# Getting Review #90/30000
# Getting Review #91/30000
# Getting Review #92/30000
# Getting Review #93/30000
# Getting Review #94/30000
# Getting Review #95/30000
# Getting Review #96/30000
# Getting Review #97/30000
# Getting Review #98/30000
# Getting Review #99/30000
# Getting Review #100/30000
# Getting Review #101/30000
# Getting Review #102/30000
# Getting Review #103/30000
# Getting Review #104/30000
# Getting Review #105/30000
# Getting Review #106/30000
# Getting Review #107/30000
# Getting Review #108/30000
# Getting Review #109/30000
# Getting Review #110/30000
# Getting Review #111/30000
# Getting Review #112/30000
# Getting Review #113/30000
# Getting Review #114/30000
# Getting Review #115/30000
# Getting Review #116/30000
# Getting Review #117/30000
# Getting Review #118/30000
# Getting Review #119/30000
# Getting Review #120/30000
# Getting Review #121/30000
# Getting Review #122/30000
# Getting Review #123/30000
# Getting Review #124/30000
# Getting Review #125/30000
# Getting Review #126/30000
# Getting Review #127/30000
# Getting Review #128/30000
# Getting Review #129/30000
# Getting Review #130/30000
# Getting Review #131/30000
# Getting Review #132/30000
# Getting Review #133/30000
# Getting Review #134/30000
# Getting Review #135/30000
# Getting Review #136/30000
# Getting Review #137/30000
# Getting Review #138/30000
# Getting Review #139/30000
# Getting Review #140/30000
# Getting Review #141/30000
# Getting Review #142/30000
# Getting Review #143/30000
# Getting Review #144/30000
# Getting Review #145/30000
# Getting Review #146/30000
# Getting Review #147/30000
# Getting Review #148/30000
# Getting Review #149/30000
# Getting Review #150/30000
# Getting Review #151/30000
# Getting Review #152/30000
# Getting Review #153/30000
# Getting Review #154/30000
# Getting Review #155/30000
# Getting Review #156/30000
# Getting Review #157/30000
# Getting Review #158/30000
# Getting Review #159/30000
# Getting Review #160/30000
# Getting Review #161/30000
# Getting Review #162/30000
# Getting Review #163/30000
# Getting Review #164/30000
# Getting Review #165/30000
# Getting Review #166/30000
# Getting Review #167/30000
# Getting Review #168/30000
# Getting Review #169/30000
# Getting Review #170/30000
# Getting Review #171/30000
# Getting Review #172/30000
# Getting Review #173/30000
# Getting Review #174/30000
# Getting Review #175/30000
# Getting Review #176/30000
# Getting Review #177/30000
# Getting Review #178/30000
# Getting Review #179/30000
# Getting Review #180/30000
# Getting Review #181/30000
# Getting Review #182/30000
# Getting Review #183/30000
# Getting Review #184/30000
# Getting Review #185/30000
# Getting Review #186/30000
# Getting Review #187/30000
# Getting Review #188/30000
# Getting Review #189/30000
# Getting Review #190/30000
# Getting Review #191/30000
# Getting Review #192/30000
# Getting Review #193/30000
# Getting Review #194/30000
# Getting Review #195/30000
# Getting Review #196/30000
# Getting Review #197/30000
# Getting Review #198/30000
# Getting Review #199/30000
# Getting Review #200/30000
# Getting Review #201/30000
# Getting Review #202/30000
# Getting Review #203/30000
# Getting Review #204/30000
# Getting Review #205/30000
# Getting Review #206/30000
# Getting Review #207/30000
# Getting Review #208/30000
# Getting Review #209/30000
# Getting Review #210/30000
# Getting Review #211/30000
# Getting Review #212/30000
# Getting Review #213/30000
# Getting Review #214/30000
# Getting Review #215/30000
# Getting Review #216/30000
# Getting Review #217/30000
# Getting Review #218/30000
# Getting Review #219/30000
# Getting Review #220/30000
# Getting Review #221/30000
# Getting Review #222/30000
# Getting Review #223/30000
# Getting Review #224/30000
# Getting Review #225/30000
# Getting Review #226/30000
# Getting Review #227/30000
# Getting Review #228/30000
# Getting Review #229/30000
# Getting Review #230/30000
# Getting Review #231/30000
# Getting Review #232/30000
# Getting Review #233/30000
# Getting Review #234/30000
# Getting Review #235/30000
# Getting Review #236/30000
# Getting Review #237/30000
# Getting Review #238/30000
# Getting Review #239/30000
# Getting Review #240/30000
# Getting Review #241/30000
# Getting Review #242/30000
# Getting Review #243/30000
# Getting Review #244/30000
# Getting Review #245/30000
# Getting Review #246/30000
# Getting Review #247/30000
# Getting Review #248/30000
# Getting Review #249/30000
# Getting Review #250/30000
# Getting Review #251/30000
# Getting Review #252/30000
# Getting Review #253/30000
# Getting Review #254/30000
# Getting Review #255/30000
# Getting Review #256/30000
# Getting Review #257/30000
# Getting Review #258/30000
# Getting Review #259/30000
# Getting Review #260/30000
# Getting Review #261/30000
# Getting Review #262/30000
# Getting Review #263/30000
# Getting Review #264/30000
# Getting Review #265/30000
# Getting Review #266/30000
# Getting Review #267/30000
# Getting Review #268/30000
# Getting Review #269/30000
# Getting Review #270/30000
# Getting Review #271/30000
# Getting Review #272/30000
# Getting Review #273/30000
# Getting Review #274/30000
# Getting Review #275/30000
# Getting Review #276/30000
# Getting Review #277/30000
# Getting Review #278/30000
# Getting Review #279/30000
# Getting Review #280/30000
# Getting Review #281/30000
# Getting Review #282/30000
# Getting Review #283/30000
# Getting Review #284/30000
# Getting Review #285/30000
# Getting Review #286/30000
# Getting Review #287/30000
# Getting Review #288/30000
# Getting Review #289/30000
# Getting Review #290/30000
# Getting Review #291/30000
# Getting Review #292/30000
# Getting Review #293/30000
# Getting Review #294/30000
# Getting Review #295/30000
# Getting Review #296/30000
# Getting Review #297/30000
# Getting Review #298/30000
# Getting Review #299/30000
# Getting Review #300/30000
# Getting Review #301/30000
# Getting Review #302/30000
# Getting Review #303/30000
# Getting Review #304/30000
# Getting Review #305/30000
# Getting Review #306/30000
# Getting Review #307/30000
# Getting Review #308/30000
# Getting Review #309/30000
# Getting Review #310/30000
# Getting Review #311/30000
# Getting Review #312/30000
# Getting Review #313/30000
# Getting Review #314/30000
# Getting Review #315/30000
# Getting Review #316/30000
# Getting Review #317/30000
# Getting Review #318/30000
# Getting Review #319/30000
# Getting Review #320/30000
# Getting Review #321/30000
# Getting Review #322/30000
# Getting Review #323/30000
# Getting Review #324/30000
# Getting Review #325/30000
# Getting Review #326/30000
# Getting Review #327/30000
# Getting Review #328/30000
# Getting Review #329/30000
# Getting Review #330/30000
# Getting Review #331/30000
# Getting Review #332/30000
# Getting Review #333/30000
# Getting Review #334/30000
# Getting Review #335/30000
# Getting Review #336/30000
# Getting Review #337/30000
# Getting Review #338/30000
# Getting Review #339/30000
# Getting Review #340/30000
# Getting Review #341/30000
# Getting Review #342/30000
# Getting Review #343/30000
# Getting Review #344/30000
# Getting Review #345/30000
# Getting Review #346/30000
# Getting Review #347/30000
# Getting Review #348/30000
# Getting Review #349/30000
# Getting Review #350/30000
# Getting Review #351/30000
# Getting Review #352/30000
# Getting Review #353/30000
# Getting Review #354/30000
# Getting Review #355/30000
# Getting Review #356/30000
# Getting Review #357/30000
# Getting Review #358/30000
# Getting Review #359/30000
# Getting Review #360/30000
# Getting Review #361/30000
# Getting Review #362/30000
# Getting Review #363/30000
# Getting Review #364/30000
# Getting Review #365/30000
# Getting Review #366/30000
# Getting Review #367/30000
# Getting Review #368/30000
# Getting Review #369/30000
# Getting Review #370/30000
# Getting Review #371/30000
# Getting Review #372/30000
# Getting Review #373/30000
# Getting Review #374/30000
# Getting Review #375/30000
# Getting Review #376/30000
# Getting Review #377/30000
# Getting Review #378/30000
# Getting Review #379/30000
# Getting Review #380/30000
# Getting Review #381/30000
# Getting Review #382/30000
# Getting Review #383/30000
# Getting Review #384/30000
# Getting Review #385/30000
# Getting Review #386/30000
# Getting Review #387/30000
# Getting Review #388/30000
# Getting Review #389/30000
# Getting Review #390/30000
# Getting Review #391/30000
# Getting Review #392/30000
# Getting Review #393/30000
# Getting Review #394/30000
# Getting Review #395/30000
# Getting Review #396/30000
# Getting Review #397/30000
# Getting Review #398/30000
# Getting Review #399/30000
# Getting Review #400/30000
# Getting Review #401/30000
# Getting Review #402/30000
# Getting Review #403/30000
# Getting Review #404/30000
# Getting Review #405/30000
# Getting Review #406/30000
# Getting Review #407/30000
# Getting Review #408/30000
# Getting Review #409/30000
# Getting Review #410/30000
# Getting Review #411/30000
# Getting Review #412/30000
# Getting Review #413/30000
# Getting Review #414/30000
# Getting Review #415/30000
# Getting Review #416/30000
# Getting Review #417/30000
# Getting Review #418/30000
# Getting Review #419/30000
# Getting Review #420/30000
# Getting Review #421/30000
# Getting Review #422/30000
# Getting Review #423/30000
# Getting Review #424/30000
# Getting Review #425/30000
# Getting Review #426/30000
# Getting Review #427/30000
# Getting Review #428/30000
# Getting Review #429/30000
# Getting Review #430/30000
# Getting Review #431/30000
# Getting Review #432/30000
# Getting Review #433/30000
# Getting Review #434/30000
# Getting Review #435/30000
# Getting Review #436/30000
# Getting Review #437/30000
# Getting Review #438/30000
# Getting Review #439/30000
# Getting Review #440/30000
# Getting Review #441/30000
# Getting Review #442/30000
# Getting Review #443/30000
# Getting Review #444/30000
# Getting Review #445/30000
# Getting Review #446/30000
# Getting Review #447/30000
# Getting Review #448/30000
# Getting Review #449/30000
# Getting Review #450/30000
# Getting Review #451/30000
# Getting Review #452/30000
# Getting Review #453/30000
# Getting Review #454/30000
# Getting Review #455/30000
# Getting Review #456/30000
# Getting Review #457/30000
# Getting Review #458/30000
# Getting Review #459/30000
# Getting Review #460/30000
# Getting Review #461/30000
# Getting Review #462/30000
# Getting Review #463/30000
# Getting Review #464/30000
# Getting Review #465/30000
# Getting Review #466/30000
# Getting Review #467/30000
# Getting Review #468/30000
# Getting Review #469/30000
# Getting Review #470/30000
# Getting Review #471/30000
# Getting Review #472/30000
# Getting Review #473/30000
# Getting Review #474/30000
# Getting Review #475/30000
# Getting Review #476/30000
# Getting Review #477/30000
# Getting Review #478/30000
# Getting Review #479/30000
# Getting Review #480/30000
# Getting Review #481/30000
# Getting Review #482/30000
# Getting Review #483/30000
# Getting Review #484/30000
# Getting Review #485/30000
# Getting Review #486/30000
# Getting Review #487/30000
# Getting Review #488/30000
# Getting Review #489/30000
# Getting Review #490/30000
# Getting Review #491/30000
# Getting Review #492/30000
# Getting Review #493/30000
# Getting Review #494/30000
# Getting Review #495/30000
# Getting Review #496/30000
# Getting Review #497/30000
# Getting Review #498/30000
# Getting Review #499/30000
# Getting Review #500/30000
# Getting Review #501/30000
# Getting Review #502/30000
# Getting Review #503/30000
# Getting Review #504/30000
# Getting Review #505/30000
# Getting Review #506/30000
# Getting Review #507/30000
# Getting Review #508/30000
# Getting Review #509/30000
# Getting Review #510/30000
# Getting Review #511/30000
# Getting Review #512/30000
# Getting Review #513/30000
# Getting Review #514/30000
# Getting Review #515/30000
# Getting Review #516/30000
# Getting Review #517/30000
# Getting Review #518/30000
# Getting Review #519/30000
# Getting Review #520/30000
# Getting Review #521/30000
# Getting Review #522/30000
# Getting Review #523/30000
# Getting Review #524/30000
# Getting Review #525/30000
# Getting Review #526/30000
# Getting Review #527/30000
# Getting Review #528/30000
# Getting Review #529/30000
# Getting Review #530/30000
# Getting Review #531/30000
# Getting Review #532/30000
# Getting Review #533/30000
# Getting Review #534/30000
# Getting Review #535/30000
# Getting Review #536/30000
# Getting Review #537/30000
# Getting Review #538/30000
# Getting Review #539/30000
# Getting Review #540/30000
# Getting Review #541/30000
# Getting Review #542/30000
# Getting Review #543/30000
# Getting Review #544/30000
# Getting Review #545/30000
# Getting Review #546/30000
# Getting Review #547/30000
# Getting Review #548/30000
# Getting Review #549/30000
# Getting Review #550/30000
# Getting Review #551/30000
# Getting Review #552/30000
# Getting Review #553/30000
# Getting Review #554/30000
# Getting Review #555/30000
# Getting Review #556/30000
# Getting Review #557/30000
# Getting Review #558/30000
# Getting Review #559/30000
# Getting Review #560/30000
# Getting Review #561/30000
# Getting Review #562/30000
# Getting Review #563/30000
# Getting Review #564/30000
# Getting Review #565/30000
# Getting Review #566/30000
# Getting Review #567/30000
# Getting Review #568/30000
# Getting Review #569/30000
# Getting Review #570/30000
# Getting Review #571/30000
# Getting Review #572/30000
# Getting Review #573/30000
# Getting Review #574/30000
# Getting Review #575/30000
# Getting Review #576/30000
# Getting Review #577/30000
# Getting Review #578/30000
# Getting Review #579/30000
# Getting Review #580/30000
# Getting Review #581/30000
# Getting Review #582/30000
# Getting Review #583/30000
# Getting Review #584/30000
# Getting Review #585/30000
# Getting Review #586/30000
# Getting Review #587/30000
# Getting Review #588/30000
# Getting Review #589/30000
# Getting Review #590/30000
# Getting Review #591/30000
# Getting Review #592/30000
# Getting Review #593/30000
# Getting Review #594/30000
# Getting Review #595/30000
# Getting Review #596/30000
# Getting Review #597/30000
# Getting Review #598/30000
# Getting Review #599/30000
# Getting Review #600/30000
# Getting Review #601/30000
# Getting Review #602/30000
# Getting Review #603/30000
# Getting Review #604/30000
# Getting Review #605/30000
# Getting Review #606/30000
# Getting Review #607/30000
# Getting Review #608/30000
# Getting Review #609/30000
# Getting Review #610/30000
# Getting Review #611/30000
# Getting Review #612/30000
# Getting Review #613/30000
# Getting Review #614/30000
# Getting Review #615/30000
# Getting Review #616/30000
# Getting Review #617/30000
# Getting Review #618/30000
# Getting Review #619/30000
# Getting Review #620/30000
# Getting Review #621/30000
# Getting Review #622/30000
# Getting Review #623/30000
# Getting Review #624/30000
# Getting Review #625/30000
# Getting Review #626/30000
# Getting Review #627/30000
# Getting Review #628/30000
# Getting Review #629/30000
# Getting Review #630/30000
# Getting Review #631/30000
# Getting Review #632/30000
# Getting Review #633/30000
# Getting Review #634/30000
# Getting Review #635/30000
# Getting Review #636/30000
# Getting Review #637/30000
# Getting Review #638/30000
# Getting Review #639/30000
# Getting Review #640/30000
# Getting Review #641/30000
# Getting Review #642/30000
# Getting Review #643/30000
# Getting Review #644/30000
# Getting Review #645/30000
# Getting Review #646/30000
# Getting Review #647/30000
# Getting Review #648/30000
# Getting Review #649/30000
# Getting Review #650/30000
# Getting Review #651/30000
# Getting Review #652/30000
# Getting Review #653/30000
# Getting Review #654/30000
# Getting Review #655/30000
# Getting Review #656/30000
# Getting Review #657/30000
# Getting Review #658/30000
# Getting Review #659/30000
# Getting Review #660/30000
# Getting Review #661/30000
# Getting Review #662/30000
# Getting Review #663/30000
# Getting Review #664/30000
# Getting Review #665/30000
# Getting Review #666/30000
# Getting Review #667/30000
# Getting Review #668/30000
# Getting Review #669/30000
# Getting Review #670/30000
# Getting Review #671/30000
# Getting Review #672/30000
# Getting Review #673/30000
# Getting Review #674/30000
# Getting Review #675/30000
# Getting Review #676/30000
# Getting Review #677/30000
# Getting Review #678/30000
# Getting Review #679/30000
# Getting Review #680/30000
# Getting Review #681/30000
# Getting Review #682/30000
# Getting Review #683/30000
# Getting Review #684/30000
# Getting Review #685/30000
# Getting Review #686/30000
# Getting Review #687/30000
# Getting Review #688/30000
# Getting Review #689/30000
# Getting Review #690/30000
# Getting Review #691/30000
# Getting Review #692/30000
# Getting Review #693/30000
# Getting Review #694/30000
# Getting Review #695/30000
# Getting Review #696/30000
# Getting Review #697/30000
# Getting Review #698/30000
# Getting Review #699/30000
# Getting Review #700/30000
# Getting Review #701/30000
# Getting Review #702/30000
# Getting Review #703/30000
# Getting Review #704/30000
# Getting Review #705/30000
# Getting Review #706/30000
# Getting Review #707/30000
# Getting Review #708/30000
# Getting Review #709/30000
# Getting Review #710/30000
# Getting Review #711/30000
# Getting Review #712/30000
# Getting Review #713/30000
# Getting Review #714/30000
# Getting Review #715/30000
# Getting Review #716/30000
# Getting Review #717/30000
# Getting Review #718/30000
# Getting Review #719/30000
# Getting Review #720/30000
# Getting Review #721/30000
# Getting Review #722/30000
# Getting Review #723/30000
# Getting Review #724/30000
# Getting Review #725/30000
# Getting Review #726/30000
# Getting Review #727/30000
# Getting Review #728/30000
# Getting Review #729/30000
# Getting Review #730/30000
# Getting Review #731/30000
# Getting Review #732/30000
# Getting Review #733/30000
# Getting Review #734/30000
# Getting Review #735/30000
# Getting Review #736/30000
# Getting Review #737/30000
# Getting Review #738/30000
# Getting Review #739/30000
# Getting Review #740/30000
# Getting Review #741/30000
# Getting Review #742/30000
# Getting Review #743/30000
# Getting Review #744/30000
# Getting Review #745/30000
# Getting Review #746/30000
# Getting Review #747/30000
# Getting Review #748/30000
# Getting Review #749/30000
# Getting Review #750/30000
# Getting Review #751/30000
# Getting Review #752/30000
# Getting Review #753/30000
# Getting Review #754/30000
# Getting Review #755/30000
# Getting Review #756/30000
# Getting Review #757/30000
# Getting Review #758/30000
# Getting Review #759/30000
# Getting Review #760/30000
# Getting Review #761/30000
# Getting Review #762/30000
# Getting Review #763/30000
# Getting Review #764/30000
# Getting Review #765/30000
# Getting Review #766/30000
# Getting Review #767/30000
# Getting Review #768/30000
# Getting Review #769/30000
# Getting Review #770/30000
# Getting Review #771/30000
# Getting Review #772/30000
# Getting Review #773/30000
# Getting Review #774/30000
# Getting Review #775/30000
# Getting Review #776/30000
# Getting Review #777/30000
# Getting Review #778/30000
# Getting Review #779/30000
# Getting Review #780/30000
# Getting Review #781/30000
# Getting Review #782/30000
# Getting Review #783/30000
# Getting Review #784/30000
# Getting Review #785/30000
# Getting Review #786/30000
# Getting Review #787/30000
# Getting Review #788/30000
# Getting Review #789/30000
# Getting Review #790/30000
# Getting Review #791/30000
# Getting Review #792/30000
# Getting Review #793/30000
# Getting Review #794/30000
# Getting Review #795/30000
# Getting Review #796/30000
# Getting Review #797/30000
# Getting Review #798/30000
# Getting Review #799/30000
# Getting Review #800/30000
# Getting Review #801/30000
# Getting Review #802/30000
# Getting Review #803/30000
# Getting Review #804/30000
# Getting Review #805/30000
# Getting Review #806/30000
# Getting Review #807/30000
# Getting Review #808/30000
# Getting Review #809/30000
# Getting Review #810/30000
# Getting Review #811/30000
# Getting Review #812/30000
# Getting Review #813/30000
# Getting Review #814/30000
# Getting Review #815/30000
# Getting Review #816/30000
# Getting Review #817/30000
# Getting Review #818/30000
# Getting Review #819/30000
# Getting Review #820/30000
# Getting Review #821/30000
# Getting Review #822/30000
# Getting Review #823/30000
# Getting Review #824/30000
# Getting Review #825/30000
# Getting Review #826/30000
# Getting Review #827/30000
# Getting Review #828/30000
# Getting Review #829/30000
# Getting Review #830/30000
# Getting Review #831/30000
# Getting Review #832/30000
# Getting Review #833/30000
# Getting Review #834/30000
# Getting Review #835/30000
# Getting Review #836/30000
# Getting Review #837/30000
# Getting Review #838/30000
# Getting Review #839/30000
# Getting Review #840/30000
# Getting Review #841/30000
# Getting Review #842/30000
# Getting Review #843/30000
# Getting Review #844/30000
# Getting Review #845/30000
# Getting Review #846/30000
# Getting Review #847/30000
# Getting Review #848/30000
# Getting Review #849/30000
# Getting Review #850/30000
# Getting Review #851/30000
# Getting Review #852/30000
# Getting Review #853/30000
# Getting Review #854/30000
# Getting Review #855/30000
# Getting Review #856/30000
# Getting Review #857/30000
# Getting Review #858/30000
# Getting Review #859/30000
# Getting Review #860/30000
# Getting Review #861/30000
# Getting Review #862/30000
# Getting Review #863/30000
# Getting Review #864/30000
# Getting Review #865/30000
# Getting Review #866/30000
# Getting Review #867/30000
# Getting Review #868/30000
# Getting Review #869/30000
# Getting Review #870/30000
# Getting Review #871/30000
# Getting Review #872/30000
# Getting Review #873/30000
# Getting Review #874/30000
# Getting Review #875/30000
# Getting Review #876/30000
# Getting Review #877/30000
# Getting Review #878/30000
# Getting Review #879/30000
# Getting Review #880/30000
# Getting Review #881/30000
# Getting Review #882/30000
# Getting Review #883/30000
# Getting Review #884/30000
# Getting Review #885/30000
# Getting Review #886/30000
# Getting Review #887/30000
# Getting Review #888/30000
# Getting Review #889/30000
# Getting Review #890/30000
# Getting Review #891/30000
# Getting Review #892/30000
# Getting Review #893/30000
# Getting Review #894/30000
# Getting Review #895/30000
# Getting Review #896/30000
# Getting Review #897/30000
# Getting Review #898/30000
# Getting Review #899/30000
# Getting Review #900/30000
# Getting Review #901/30000
# Getting Review #902/30000
# Getting Review #903/30000
# Getting Review #904/30000
# Getting Review #905/30000
# Getting Review #906/30000
# Getting Review #907/30000
# Getting Review #908/30000
# Getting Review #909/30000
# Getting Review #910/30000
# Getting Review #911/30000
# Getting Review #912/30000
# Getting Review #913/30000
# Getting Review #914/30000
# Getting Review #915/30000
# Getting Review #916/30000
# Getting Review #917/30000
# Getting Review #918/30000
# Getting Review #919/30000
# Getting Review #920/30000
# Getting Review #921/30000
# Getting Review #922/30000
# Getting Review #923/30000
# Getting Review #924/30000
# Getting Review #925/30000
# Getting Review #926/30000
# Getting Review #927/30000
# Getting Review #928/30000
# Getting Review #929/30000
# Getting Review #930/30000
# Getting Review #931/30000
# Getting Review #932/30000
# Getting Review #933/30000
# Getting Review #934/30000
# Getting Review #935/30000
# Getting Review #936/30000
# Getting Review #937/30000
# Getting Review #938/30000
# Getting Review #939/30000
# Getting Review #940/30000
# Getting Review #941/30000
# Getting Review #942/30000
# Getting Review #943/30000
# Getting Review #944/30000
# Getting Review #945/30000
# Getting Review #946/30000
# Getting Review #947/30000
# Getting Review #948/30000
# Getting Review #949/30000
# Getting Review #950/30000
# Getting Review #951/30000
# Getting Review #952/30000
# Getting Review #953/30000
# Getting Review #954/30000
# Getting Review #955/30000
# Getting Review #956/30000
# Getting Review #957/30000
# Getting Review #958/30000
# Getting Review #959/30000
# Getting Review #960/30000
# Getting Review #961/30000
# Getting Review #962/30000
# Getting Review #963/30000
# Getting Review #964/30000
# Getting Review #965/30000
# Getting Review #966/30000
# Getting Review #967/30000
# Getting Review #968/30000
# Getting Review #969/30000
# Getting Review #970/30000
# Getting Review #971/30000
# Getting Review #972/30000
# Getting Review #973/30000
# Getting Review #974/30000
# Getting Review #975/30000
# Getting Review #976/30000
# Getting Review #977/30000
# Getting Review #978/30000
# Getting Review #979/30000
# Getting Review #980/30000
# Getting Review #981/30000
# Getting Review #982/30000
# Getting Review #983/30000
# Getting Review #984/30000
# Getting Review #985/30000
# Getting Review #986/30000
# Getting Review #987/30000
# Getting Review #988/30000
# Getting Review #989/30000
# Getting Review #990/30000
# Getting Review #991/30000
# Getting Review #992/30000
# Getting Review #993/30000
# Getting Review #994/30000
# Getting Review #995/30000
# Getting Review #996/30000
# Getting Review #997/30000
# Getting Review #998/30000
# Getting Review #999/30000
# Getting Review #1000/30000
# Getting Review #1001/30000
# Getting Review #1002/30000
# Getting Review #1003/30000
# Getting Review #1004/30000
# Getting Review #1005/30000
# Getting Review #1006/30000
# Getting Review #1007/30000
# Getting Review #1008/30000
# Getting Review #1009/30000
# Getting Review #1010/30000
# Getting Review #1011/30000
# Getting Review #1012/30000
# Getting Review #1013/30000
# Getting Review #1014/30000
# Getting Review #1015/30000
# Getting Review #1016/30000
# Getting Review #1017/30000
# Getting Review #1018/30000
# Getting Review #1019/30000
# Getting Review #1020/30000
# Getting Review #1021/30000
# Getting Review #1022/30000
# Getting Review #1023/30000
# Getting Review #1024/30000
# Getting Review #1025/30000
# Getting Review #1026/30000
# Getting Review #1027/30000
# Getting Review #1028/30000
# Getting Review #1029/30000
# Getting Review #1030/30000
# Getting Review #1031/30000
# Getting Review #1032/30000
# Getting Review #1033/30000
# Getting Review #1034/30000
# Getting Review #1035/30000
# Getting Review #1036/30000
# Getting Review #1037/30000
# Getting Review #1038/30000
# Getting Review #1039/30000
# Getting Review #1040/30000
# Getting Review #1041/30000
# Getting Review #1042/30000
# Getting Review #1043/30000
# Getting Review #1044/30000
# Getting Review #1045/30000
# Getting Review #1046/30000
# Getting Review #1047/30000
# Getting Review #1048/30000
# Getting Review #1049/30000
# Getting Review #1050/30000
# Getting Review #1051/30000
# Getting Review #1052/30000
# Getting Review #1053/30000
# Getting Review #1054/30000
# Getting Review #1055/30000
# Getting Review #1056/30000
# Getting Review #1057/30000
# Getting Review #1058/30000
# Getting Review #1059/30000
# Getting Review #1060/30000
# Getting Review #1061/30000
# Getting Review #1062/30000
# Getting Review #1063/30000
# Getting Review #1064/30000
# Getting Review #1065/30000
# Getting Review #1066/30000
# Getting Review #1067/30000
# Getting Review #1068/30000
# Getting Review #1069/30000
# Getting Review #1070/30000
# Getting Review #1071/30000
# Getting Review #1072/30000
# Getting Review #1073/30000
# Getting Review #1074/30000
# Getting Review #1075/30000
# Getting Review #1076/30000
# Getting Review #1077/30000
# Getting Review #1078/30000
# Getting Review #1079/30000
# Getting Review #1080/30000
# Getting Review #1081/30000
# Getting Review #1082/30000
# Getting Review #1083/30000
# Getting Review #1084/30000
# Getting Review #1085/30000
# Getting Review #1086/30000
# Getting Review #1087/30000
# Getting Review #1088/30000
# Getting Review #1089/30000
# Getting Review #1090/30000
# Getting Review #1091/30000
# Getting Review #1092/30000
# Getting Review #1093/30000
# Getting Review #1094/30000
# Getting Review #1095/30000
# Getting Review #1096/30000
# Getting Review #1097/30000
# Getting Review #1098/30000
# Getting Review #1099/30000
# Getting Review #1100/30000
# Getting Review #1101/30000
# Getting Review #1102/30000
# Getting Review #1103/30000
# Getting Review #1104/30000
# Getting Review #1105/30000
# Getting Review #1106/30000
# Getting Review #1107/30000
# Getting Review #1108/30000
# Getting Review #1109/30000
# Getting Review #1110/30000
# Getting Review #1111/30000
# Getting Review #1112/30000
# Getting Review #1113/30000
# Getting Review #1114/30000
# Getting Review #1115/30000
# Getting Review #1116/30000
# Getting Review #1117/30000
# Getting Review #1118/30000
# Getting Review #1119/30000
# Getting Review #1120/30000
# Getting Review #1121/30000
# Getting Review #1122/30000
# Getting Review #1123/30000
# Getting Review #1124/30000
# Getting Review #1125/30000
# Getting Review #1126/30000
# Getting Review #1127/30000
# Getting Review #1128/30000
# Getting Review #1129/30000
# Getting Review #1130/30000
# Getting Review #1131/30000
# Getting Review #1132/30000
# Getting Review #1133/30000
# Getting Review #1134/30000
# Getting Review #1135/30000
# Getting Review #1136/30000
# Getting Review #1137/30000
# Getting Review #1138/30000
# Getting Review #1139/30000
# Getting Review #1140/30000
# Getting Review #1141/30000
# Getting Review #1142/30000
# Getting Review #1143/30000
# Getting Review #1144/30000
# Getting Review #1145/30000
# Getting Review #1146/30000
# Getting Review #1147/30000
# Getting Review #1148/30000
# Getting Review #1149/30000
# Getting Review #1150/30000
# Getting Review #1151/30000
# Getting Review #1152/30000
# Getting Review #1153/30000
# Getting Review #1154/30000
# Getting Review #1155/30000
# Getting Review #1156/30000
# Getting Review #1157/30000
# Getting Review #1158/30000
# Getting Review #1159/30000
# Getting Review #1160/30000
# Getting Review #1161/30000
# Getting Review #1162/30000
# Getting Review #1163/30000
# Getting Review #1164/30000
# Getting Review #1165/30000
# Getting Review #1166/30000
# Getting Review #1167/30000
# Getting Review #1168/30000
# Getting Review #1169/30000
# Getting Review #1170/30000
# Getting Review #1171/30000
# Getting Review #1172/30000
# Getting Review #1173/30000
# Getting Review #1174/30000
# Getting Review #1175/30000
# Getting Review #1176/30000
# Getting Review #1177/30000
# Getting Review #1178/30000
# Getting Review #1179/30000
# Getting Review #1180/30000
# Getting Review #1181/30000
# Getting Review #1182/30000
# Getting Review #1183/30000
# Getting Review #1184/30000
# Getting Review #1185/30000
# Getting Review #1186/30000
# Getting Review #1187/30000
# Getting Review #1188/30000
# Getting Review #1189/30000
# Getting Review #1190/30000
# Getting Review #1191/30000
# Getting Review #1192/30000
# Getting Review #1193/30000
# Getting Review #1194/30000
# Getting Review #1195/30000
# Getting Review #1196/30000
# Getting Review #1197/30000
# Getting Review #1198/30000
# Getting Review #1199/30000
# Getting Review #1200/30000
# Getting Review #1201/30000
# Getting Review #1202/30000
# Getting Review #1203/30000
# Getting Review #1204/30000
# Getting Review #1205/30000
# Getting Review #1206/30000
# Getting Review #1207/30000
# Getting Review #1208/30000
# Getting Review #1209/30000
# Getting Review #1210/30000
# Getting Review #1211/30000
# Getting Review #1212/30000
# Getting Review #1213/30000
# Getting Review #1214/30000
# Getting Review #1215/30000
# Getting Review #1216/30000
# Getting Review #1217/30000
# Getting Review #1218/30000
# Getting Review #1219/30000
# Getting Review #1220/30000
# Getting Review #1221/30000
# Getting Review #1222/30000
# Getting Review #1223/30000
# Getting Review #1224/30000
# Getting Review #1225/30000
# Getting Review #1226/30000
# Getting Review #1227/30000
# Getting Review #1228/30000
# Getting Review #1229/30000
# Getting Review #1230/30000
# Getting Review #1231/30000
# Getting Review #1232/30000
# Getting Review #1233/30000
# Getting Review #1234/30000
# Getting Review #1235/30000
# Getting Review #1236/30000
# Getting Review #1237/30000
# Getting Review #1238/30000
# Getting Review #1239/30000
# Getting Review #1240/30000
# Getting Review #1241/30000
# Getting Review #1242/30000
# Getting Review #1243/30000
# Getting Review #1244/30000
# Getting Review #1245/30000
# Getting Review #1246/30000
# Getting Review #1247/30000
# Getting Review #1248/30000
# Getting Review #1249/30000
# Getting Review #1250/30000
# Getting Review #1251/30000
# Getting Review #1252/30000
# Getting Review #1253/30000
# Getting Review #1254/30000
# Getting Review #1255/30000
# Getting Review #1256/30000
# Getting Review #1257/30000
# Getting Review #1258/30000
# Getting Review #1259/30000
# Getting Review #1260/30000
# Getting Review #1261/30000
# Getting Review #1262/30000
# Getting Review #1263/30000
# Getting Review #1264/30000
# Getting Review #1265/30000
# Getting Review #1266/30000
# Getting Review #1267/30000
# Getting Review #1268/30000
# Getting Review #1269/30000
# Getting Review #1270/30000
# Getting Review #1271/30000
# Getting Review #1272/30000
# Getting Review #1273/30000
# Getting Review #1274/30000
# Getting Review #1275/30000
# Getting Review #1276/30000
# Getting Review #1277/30000
# Getting Review #1278/30000
# Getting Review #1279/30000
# Getting Review #1280/30000
# Getting Review #1281/30000
# Getting Review #1282/30000
# Getting Review #1283/30000
# Getting Review #1284/30000
# Getting Review #1285/30000
# Getting Review #1286/30000
# Getting Review #1287/30000
# Getting Review #1288/30000
# Getting Review #1289/30000
# Getting Review #1290/30000
# Getting Review #1291/30000
# Getting Review #1292/30000
# Getting Review #1293/30000
# Getting Review #1294/30000
# Getting Review #1295/30000
# Getting Review #1296/30000
# Getting Review #1297/30000
# Getting Review #1298/30000
# Getting Review #1299/30000
# Getting Review #1300/30000
# Getting Review #1301/30000
# Getting Review #1302/30000
# Getting Review #1303/30000
# Getting Review #1304/30000
# Getting Review #1305/30000
# Getting Review #1306/30000
# Getting Review #1307/30000
# Getting Review #1308/30000
# Getting Review #1309/30000
# Getting Review #1310/30000
# Getting Review #1311/30000
# Getting Review #1312/30000
# Getting Review #1313/30000
# Getting Review #1314/30000
# Getting Review #1315/30000
# Getting Review #1316/30000
# Getting Review #1317/30000
# Getting Review #1318/30000
# Getting Review #1319/30000
# Getting Review #1320/30000
# Getting Review #1321/30000
# Getting Review #1322/30000
# Getting Review #1323/30000
# Getting Review #1324/30000
# Getting Review #1325/30000
# Getting Review #1326/30000
# Getting Review #1327/30000
# Getting Review #1328/30000
# Getting Review #1329/30000
# Getting Review #1330/30000
# Getting Review #1331/30000
# Getting Review #1332/30000
# Getting Review #1333/30000
# Getting Review #1334/30000
# Getting Review #1335/30000
# Getting Review #1336/30000
# Getting Review #1337/30000
# Getting Review #1338/30000
# Getting Review #1339/30000
# Getting Review #1340/30000
# Getting Review #1341/30000
# Getting Review #1342/30000
# Getting Review #1343/30000
# Getting Review #1344/30000
# Getting Review #1345/30000
# Getting Review #1346/30000
# Getting Review #1347/30000
# Getting Review #1348/30000
# Getting Review #1349/30000
# Getting Review #1350/30000
# Getting Review #1351/30000
# Getting Review #1352/30000
# Getting Review #1353/30000
# Getting Review #1354/30000
# Getting Review #1355/30000
# Getting Review #1356/30000
# Getting Review #1357/30000
# Getting Review #1358/30000
# Getting Review #1359/30000
# Getting Review #1360/30000
# Getting Review #1361/30000
# Getting Review #1362/30000
# Getting Review #1363/30000
# Getting Review #1364/30000
# Getting Review #1365/30000
# Getting Review #1366/30000
# Getting Review #1367/30000
# Getting Review #1368/30000
# Getting Review #1369/30000
# Getting Review #1370/30000
# Getting Review #1371/30000
# Getting Review #1372/30000
# Getting Review #1373/30000
# Getting Review #1374/30000
# Getting Review #1375/30000
# Getting Review #1376/30000
# Getting Review #1377/30000
# Getting Review #1378/30000
# Getting Review #1379/30000
# Getting Review #1380/30000
# Getting Review #1381/30000
# Getting Review #1382/30000
# Getting Review #1383/30000
# Getting Review #1384/30000
# Getting Review #1385/30000
# Getting Review #1386/30000
# Getting Review #1387/30000
# Getting Review #1388/30000
# Getting Review #1389/30000
# Getting Review #1390/30000
# Getting Review #1391/30000
# Getting Review #1392/30000
# Getting Review #1393/30000
# Getting Review #1394/30000
# Getting Review #1395/30000
# Getting Review #1396/30000
# Getting Review #1397/30000
# Getting Review #1398/30000
# Getting Review #1399/30000
# Getting Review #1400/30000
# Getting Review #1401/30000
# Getting Review #1402/30000
# Getting Review #1403/30000
# Getting Review #1404/30000
# Getting Review #1405/30000
# Getting Review #1406/30000
# Getting Review #1407/30000
# Getting Review #1408/30000
# Getting Review #1409/30000
# Getting Review #1410/30000
# Getting Review #1411/30000
# Getting Review #1412/30000
# Getting Review #1413/30000
# Getting Review #1414/30000
# Getting Review #1415/30000
# Getting Review #1416/30000
# Getting Review #1417/30000
# Getting Review #1418/30000
# Getting Review #1419/30000
# Getting Review #1420/30000
# Getting Review #1421/30000
# Getting Review #1422/30000
# Getting Review #1423/30000
# Getting Review #1424/30000
# Getting Review #1425/30000
# Getting Review #1426/30000
# Getting Review #1427/30000
# Getting Review #1428/30000
# Getting Review #1429/30000
# Getting Review #1430/30000
# Getting Review #1431/30000
# Getting Review #1432/30000
# Getting Review #1433/30000
# Getting Review #1434/30000
# Getting Review #1435/30000
# Getting Review #1436/30000
# Getting Review #1437/30000
# Getting Review #1438/30000
# Getting Review #1439/30000
# Getting Review #1440/30000
# Getting Review #1441/30000
# Getting Review #1442/30000
# Getting Review #1443/30000
# Getting Review #1444/30000
# Getting Review #1445/30000
# Getting Review #1446/30000
# Getting Review #1447/30000
# Getting Review #1448/30000
# Getting Review #1449/30000
# Getting Review #1450/30000
# Getting Review #1451/30000
# Getting Review #1452/30000
# Getting Review #1453/30000
# Getting Review #1454/30000
# Getting Review #1455/30000
# Getting Review #1456/30000
# Getting Review #1457/30000
# Getting Review #1458/30000
# Getting Review #1459/30000
# Getting Review #1460/30000
# Getting Review #1461/30000
# Getting Review #1462/30000
# Getting Review #1463/30000
# Getting Review #1464/30000
# Getting Review #1465/30000
# Getting Review #1466/30000
# Getting Review #1467/30000
# Getting Review #1468/30000
# Getting Review #1469/30000
# Getting Review #1470/30000
# Getting Review #1471/30000
# Getting Review #1472/30000
# Getting Review #1473/30000
# Getting Review #1474/30000
# Getting Review #1475/30000
# Getting Review #1476/30000
# Getting Review #1477/30000
# Getting Review #1478/30000
# Getting Review #1479/30000
# Getting Review #1480/30000
# Getting Review #1481/30000
# Getting Review #1482/30000
# Getting Review #1483/30000
# Getting Review #1484/30000
# Getting Review #1485/30000
# Getting Review #1486/30000
# Getting Review #1487/30000
# Getting Review #1488/30000
# Getting Review #1489/30000
# Getting Review #1490/30000
# Getting Review #1491/30000
# Getting Review #1492/30000
# Getting Review #1493/30000
# Getting Review #1494/30000
# Getting Review #1495/30000
# Getting Review #1496/30000
# Getting Review #1497/30000
# Getting Review #1498/30000
# Getting Review #1499/30000
# Getting Review #1500/30000
# Getting Review #1501/30000
# Getting Review #1502/30000
# Getting Review #1503/30000
# Getting Review #1504/30000
# Getting Review #1505/30000
# Getting Review #1506/30000
# Getting Review #1507/30000
# Getting Review #1508/30000
# Getting Review #1509/30000
# Getting Review #1510/30000
# Getting Review #1511/30000
# Getting Review #1512/30000
# Getting Review #1513/30000
# Getting Review #1514/30000
# Getting Review #1515/30000
# Getting Review #1516/30000
# Getting Review #1517/30000
# Getting Review #1518/30000
# Getting Review #1519/30000
# Getting Review #1520/30000
# Getting Review #1521/30000
# Getting Review #1522/30000
# Getting Review #1523/30000
# Getting Review #1524/30000
# Getting Review #1525/30000
# Getting Review #1526/30000
# Getting Review #1527/30000
# Getting Review #1528/30000
# Getting Review #1529/30000
# Getting Review #1530/30000
# Getting Review #1531/30000
# Getting Review #1532/30000
# Getting Review #1533/30000
# Getting Review #1534/30000
# Getting Review #1535/30000
# Getting Review #1536/30000
# Getting Review #1537/30000
# Getting Review #1538/30000
# Getting Review #1539/30000
# Getting Review #1540/30000
# Getting Review #1541/30000
# Getting Review #1542/30000
# Getting Review #1543/30000
# Getting Review #1544/30000
# Getting Review #1545/30000
# Getting Review #1546/30000
# Getting Review #1547/30000
# Getting Review #1548/30000
# Getting Review #1549/30000
# Getting Review #1550/30000
# Getting Review #1551/30000
# Getting Review #1552/30000
# Getting Review #1553/30000
# Getting Review #1554/30000
# Getting Review #1555/30000
# Getting Review #1556/30000
# Getting Review #1557/30000
# Getting Review #1558/30000
# Getting Review #1559/30000
# Getting Review #1560/30000
# Getting Review #1561/30000
# Getting Review #1562/30000
# Getting Review #1563/30000
# Getting Review #1564/30000
# Getting Review #1565/30000
# Getting Review #1566/30000
# Getting Review #1567/30000
# Getting Review #1568/30000
# Getting Review #1569/30000
# Getting Review #1570/30000
# Getting Review #1571/30000
# Getting Review #1572/30000
# Getting Review #1573/30000
# Getting Review #1574/30000
# Getting Review #1575/30000
# Getting Review #1576/30000
# Getting Review #1577/30000
# Getting Review #1578/30000
# Getting Review #1579/30000
# Getting Review #1580/30000
# Getting Review #1581/30000
# Getting Review #1582/30000
# Getting Review #1583/30000
# Getting Review #1584/30000
# Getting Review #1585/30000
# Getting Review #1586/30000
# Getting Review #1587/30000
# Getting Review #1588/30000
# Getting Review #1589/30000
# Getting Review #1590/30000
# Getting Review #1591/30000
# Getting Review #1592/30000
# Getting Review #1593/30000
# Getting Review #1594/30000
# Getting Review #1595/30000
# Getting Review #1596/30000
# Getting Review #1597/30000
# Getting Review #1598/30000
# Getting Review #1599/30000
# Getting Review #1600/30000
# Getting Review #1601/30000
# Getting Review #1602/30000
# Getting Review #1603/30000
# Getting Review #1604/30000
# Getting Review #1605/30000
# Getting Review #1606/30000
# Getting Review #1607/30000
# Getting Review #1608/30000
# Getting Review #1609/30000
# Getting Review #1610/30000
# Getting Review #1611/30000
# Getting Review #1612/30000
# Getting Review #1613/30000
# Getting Review #1614/30000
# Getting Review #1615/30000
# Getting Review #1616/30000
# Getting Review #1617/30000
# Getting Review #1618/30000
# Getting Review #1619/30000
# Getting Review #1620/30000
# Getting Review #1621/30000
# Getting Review #1622/30000
# Getting Review #1623/30000
# Getting Review #1624/30000
# Getting Review #1625/30000
# Getting Review #1626/30000
# Getting Review #1627/30000
# Getting Review #1628/30000
# Getting Review #1629/30000
# Getting Review #1630/30000
# Getting Review #1631/30000
# Getting Review #1632/30000
# Getting Review #1633/30000
# Getting Review #1634/30000
# Getting Review #1635/30000
# Getting Review #1636/30000
# Getting Review #1637/30000
# Getting Review #1638/30000
# Getting Review #1639/30000
# Getting Review #1640/30000
# Getting Review #1641/30000
# Getting Review #1642/30000
# Getting Review #1643/30000
# Getting Review #1644/30000
# Getting Review #1645/30000
# Getting Review #1646/30000
# Getting Review #1647/30000
# Getting Review #1648/30000
# Getting Review #1649/30000
# Getting Review #1650/30000
# Getting Review #1651/30000
# Getting Review #1652/30000
# Getting Review #1653/30000
# Getting Review #1654/30000
# Getting Review #1655/30000
# Getting Review #1656/30000
# Getting Review #1657/30000
# Getting Review #1658/30000
# Getting Review #1659/30000
# Getting Review #1660/30000
# Getting Review #1661/30000
# Getting Review #1662/30000
# Getting Review #1663/30000
# Getting Review #1664/30000
# Getting Review #1665/30000
# Getting Review #1666/30000
# Getting Review #1667/30000
# Getting Review #1668/30000
# Getting Review #1669/30000
# Getting Review #1670/30000
# Getting Review #1671/30000
# Getting Review #1672/30000
# Getting Review #1673/30000
# Getting Review #1674/30000
# Getting Review #1675/30000
# Getting Review #1676/30000
# Getting Review #1677/30000
# Getting Review #1678/30000
# Getting Review #1679/30000
# Getting Review #1680/30000
# Getting Review #1681/30000
# Exception occurred on review #1681. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1681)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1682/30000
# Exception occurred on review #1682. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1682)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1683/30000
# Exception occurred on review #1683. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1683)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1684/30000
# Exception occurred on review #1684. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1684)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1685/30000
# Exception occurred on review #1685. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1685)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1686/30000
# Exception occurred on review #1686. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1686)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1687/30000
# Exception occurred on review #1687. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1687)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1688/30000
# Exception occurred on review #1688. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1688)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1689/30000
# Exception occurred on review #1689. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1689)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1690/30000
# Exception occurred on review #1690. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(1690)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #1691/30000
# ...
# Exception occurred on review #6312. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6312)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6313/30000
# Exception occurred on review #6313. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6313)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6314/30000
# Exception occurred on review #6314. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6314)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6315/30000
# Exception occurred on review #6315. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6315)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6316/30000
# Exception occurred on review #6316. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6316)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6317/30000
# Exception occurred on review #6317. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6317)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6318/30000
# Exception occurred on review #6318. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6318)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6319/30000
# Exception occurred on review #6319. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6319)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6320/30000
# Exception occurred on review #6320. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6320)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6321/30000
# Exception occurred on review #6321. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6321)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6322/30000
# Exception occurred on review #6322. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6322)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6323/30000
# Exception occurred on review #6323. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6323)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6324/30000
# Exception occurred on review #6324. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6324)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6325/30000
# Exception occurred on review #6325. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6325)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6326/30000
# Exception occurred on review #6326. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6326)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6327/30000
# Exception occurred on review #6327. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6327)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6328/30000
# Exception occurred on review #6328. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6328)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6329/30000
# Exception occurred on review #6329. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6329)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6330/30000
# Exception occurred on review #6330. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6330)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6331/30000
# Exception occurred on review #6331. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6331)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6332/30000
# Exception occurred on review #6332. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6332)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6333/30000
# Exception occurred on review #6333. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6333)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6334/30000
# Exception occurred on review #6334. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6334)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6335/30000
# Exception occurred on review #6335. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6335)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6336/30000
# Exception occurred on review #6336. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6336)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6337/30000
# Exception occurred on review #6337. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6337)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6338/30000
# Exception occurred on review #6338. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6338)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6339/30000
# Exception occurred on review #6339. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6339)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6340/30000
# Exception occurred on review #6340. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6340)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6341/30000
# Exception occurred on review #6341. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6341)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6342/30000
# Exception occurred on review #6342. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6342)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6343/30000
# Exception occurred on review #6343. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6343)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6344/30000
# Exception occurred on review #6344. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6344)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6345/30000
# Exception occurred on review #6345. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6345)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6346/30000
# Exception occurred on review #6346. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6346)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6347/30000
# Exception occurred on review #6347. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6347)"}
#   (Session info: chrome=79.0.3945.130)
#
# Getting Review #6348/30000
# Exception occurred on review #6348. Skipping review. Exception:
#  Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6348)"}
#   (Session info: chrome=79.0.3945.130)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-7b44215a34e4> in <module>
#      33         # Parse the review
# ---> 34         review = Review(driver, review_num)
#      35         review.move_to()
#
# <ipython-input-3-17a026dc79b7> in __init__(self, driver, review_num)
#     135         self._css_selector = f'#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child({review_num})'
# --> 136         self._element = self._driver.find_element_by_css_selector(self._css_selector)
#     137
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#fcxH9b > div.WpDbMd > c-wiz > div > div.ZfcPIb > div > div.JNury.Ekdcne > div > div > div.W4P4ne > div:nth-child(2) > div > div:nth-child(6348)"}
#   (Session info: chrome=79.0.3945.130)
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7b44215a34e4> in <module>
#      53     except Exception as e:
#      54         print(f"Exception occurred on review #{review_num}. Skipping review. Exception: \n {e}")
# ---> 55         time.sleep(3)
#      56
#      57     review_num += 1
#
# KeyboardInterrupt:

# %%
len(results)
# Out:
# 5716

# %%
def write_results_to_json(results):
    """ Write the scraped results to a timestamped JSON output file. """
    timestamp = datetime.strftime(datetime.now(), "%Y%m%dT%H%M%S")
    filename = f"results_{timestamp}.json"
    with open(filename, 'w') as outfile:
        json.dump(results, outfile)

# %%
write_results_to_json(results)

# %%
import json


def load_results_json(file):
    with open(file, 'r') as infile:
        data = json.load(infile)
    return data

# %%
data = load_results_json("results_500reviews.json")

# %%
len(data)
# Out:
# 500

# %%
data[-1]
# Out:
# {'name': 'Matt S',
#  'date': 'January 3, 2019',
#  'text': 'This app is very handy when looking to select something new to try, the user ratings on the wines and the individual wine profiles are both very helpful and interesting.',
#  'stars': [5, 5],
#  'vivino_response': ''}

# %%
class MyArgs(object):
    
    def __init__(self, max_reviews):
        self.max_reviews = max_reviews

# %%
myargs = MyArgs(max_reviews=10)

# %%
main(myargs)
# Out:
# ***** STARTING SCRAPER *****
# Getting Review #1/10
# Getting Review #2/10
# Getting Review #3/10
# Getting Review #4/10
# Getting Review #5/10
# Getting Review #6/10
# Getting Review #7/10
# Getting Review #8/10
# Getting Review #9/10
# Getting Review #10/10
# **** FINISHED! SUCCESSFULLY SCRAPED 10 TOTAL REVIEWS! ****
